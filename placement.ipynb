# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('placement.csv')
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
import seaborn as sns

# %%
sns.scatterplot(
    x=df['cgpa'],
    y=df['resume_score'],
    hue=df['placed'],
    palette='coolwarm'
)
plt.show()

# %%
X=df[['cgpa','resume_score']]
y=df['placed']

# %%
from sklearn.linear_model import Perceptron
model=Perceptron()

# %%
model.fit(X,y)
# Out:
# Perceptron()

# %%
model.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
model.intercept_
# Out:
# array([-25.])

# %%
# %pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (2.4.2)
# Requirement already satisfied: pandas>=2.3.3 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (3.0.2)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\zaima\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=2.3.3->mlxtend) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\zaima\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~etuptools (c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etuptools (c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etuptools (c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values,y.values,clf=model,legend=2)
# Out:
# c:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(X)

# %%
acc=accuracy_score(y,y_pred)

# %%
(acc)
# Out:
# 0.75
