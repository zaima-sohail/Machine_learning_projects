# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.datasets import load_breast_cancer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
dataset=load_breast_cancer()
X=dataset.data
y=dataset.target
feature_name=dataset.feature_names
class_name=dataset.target_names

# %%
X_train,X_test,y_train,y_test=train_test_split(
    X,
    y,
    stratify=y,
    test_size=0.25
)

# %%
print("The training data:",X_train.shape[0])
print("the testing data: ",X_test.shape[0])
# Out:
# The training data: 426
# the testing data:  143

# %%
models={
    "linear":SVC(kernel='linear',C=1.0),
    "polynomial":SVC(kernel='poly',C=1.0,gamma=0.01),
    "rbf":SVC(kernel='rbf',C=1.0,degree=3)
}
results={}
for name,model in models.items():
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    acc=accuracy_score(y_test,y_pred)
    cm=confusion_matrix(y_test,y_pred)
    results[name]=(acc,cm)
