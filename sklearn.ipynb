# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
! pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\zaima\appdata\local\programs\python\python310\lib\site-packages (1.7.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\zaima\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\zaima\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\zaima\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\zaima\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (2.2.6)
# [notice] A new release of pip available: 22.3.1 -> 26.2.1
# [notice] To update, run: C:\Users\zaima\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X=np.array([[1],[3],[4],[5],[7]])
Y=np.array([3,5,7,9,11])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,7))
plt.scatter(
    X,
    Y,
    color='blue'
)
plt.title("scatter plot of X and Y")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
model=LinearRegression()
model.fit(X,Y)
y_pred=model.predict(X)
print("predicted values of model",y_pred)
# Out:
# predicted values of model [ 2.8  5.6  7.   8.4 11.2]

# %%
plt.figure(figsize=(8,7))
plt.scatter(
    X,
    Y,
    color='blue',
    label="orginial data"
)
plt.plot(
    X,
    y_pred,
    color='red',
    label="Best fit line"
)
plt.title("scatter plot of X and Y")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.xticks(rotation=30)
plt.show()
