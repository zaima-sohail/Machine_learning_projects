# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# load the dataset

# %%
dataset=load_iris()
X=dataset.data
y=dataset.target
feature_name=dataset.feature_names
class_name=dataset.target_names

# %% [markdown]
# splitting the dataset intoo train and test data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state=42,
    stratify=y,
    test_size=0.3
)

# %%
model = DecisionTreeClassifier(
    max_depth=3,
    criterion='entropy',
    random_state=42
)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

# %%
plt.figure(figsize=(10,8))
plot_tree(
    model,
    feature_names=feature_name,
    class_names=class_name,
    filled=True,
    rounded=True
)
plt.title("plot tree of load iris")
plt.show()

# %%
y_pred=model.predict(X_test)
print("the model prediction accuracy is:",y_pred)
# Out:
# the model prediction accuracy is: [2 1 2 2 2 2 1 1 0 2 0 0 2 2 0 2 1 0 0 0 1 0 1 2 2 1 1 1 1 0 2 2 2 0 2 0 0
#  0 0 2 1 0 2 2 1]

# %%
print("the accuracy score is:",accuracy_score(y_test,y_pred))
print("the classification report is:",classification_report(y_test,y_pred))
print("the confusion matrix:",confusion_matrix(y_test,y_pred))
# Out:
# the accuracy score is: 0.9333333333333333
# the classification report is:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      0.80      0.89        15
#            2       0.83      1.00      0.91        15
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45
#
# the confusion matrix: [[15  0  0]
#  [ 0 12  3]
#  [ 0  0 15]]

# %%
plt.figure(figsize=(9,8))
plt.boxplot(
    X,
    tick_labels=['sepalwidth','sepal length','petal width','petal length']
)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

flowers, counts = np.unique(y, return_counts=True)

plt.figure(figsize=(7, 5))

plt.bar(
    ["Setosa", "Versicolor", "Virginica"],
    counts
)

plt.xlabel("Flower")
plt.ylabel("Number of samples")
plt.title("Number of Iris Flowers")

plt.show()

# %%
print(flowers)
print(counts)
# Out:
# [0 1 2]
# [50 50 50]

# %%
from sklearn.datasets import load_breast_cancer
