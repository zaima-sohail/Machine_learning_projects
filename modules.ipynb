# %%
from math import sqrt
print(sqrt(4))
# Out:
# 2.0

# %%
import module
module.greet()
# Out:
# hello my name is zaima, Iam in 5th Semester of CS

# %%
import numpy as np
arr=np.array([1,2,4,5,6])
print(arr)
# Out:
# [1 2 4 5 6]
