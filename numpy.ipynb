# %%
! pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\zaima\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# [notice] A new release of pip available: 22.3.1 -> 26.2.1
# [notice] To update, run: C:\Users\zaima\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import time

# %%
arr=np.array([[1,2,3],[4,5,6]])
print(arr.shape)
# Out:
# (2, 3)

# %%
print(arr.ndim)
# Out:
# 2

# %%
print(arr.dtype)
# Out:
# int64

# %%
py_list=list(range(1_000_000))
py_result=[]
start_time=time.time()
for i in py_list:
    py_result.append(i+5)
    end_time=time.time()
print("python list time:", end_time - start_time)
# Out:
# python list time: 0.270343542098999

# %%
np_array=np.arange(1_000_000)
start_time=time.time()
np_result=np_array+5
end_time=time.time()
print("Numpy arrray time:",end_time-start_time)
# Out:
# Numpy arrray time: 0.004147052764892578

# %%
arr=np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]
