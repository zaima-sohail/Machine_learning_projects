# %%
age=21
print(age)
# Out:
# 21

# %%
type(age)
# Out:
# int

# %%
name="Zaima"
print(name)
# Out:
# Zaima

# %%
print(name + " is good girl")
# Out:
# Zaima is good girl

# %%
is_password=True

# %%
print(type(is_password))
# Out:
# <class 'bool'>
