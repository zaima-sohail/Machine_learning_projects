# %%
import numpy as np
import pandas as pd

# %%
learning_rate=0.01
epochs=10
X=np.array([1,2,3,4,5])
Y=np.array([3,4,2,5,6])

# %%
m,b=0.0,0.0
n=len(X)

# %%
for i in range(epochs):
    Y_pred=m*X+b
    cost=((Y_pred - Y)**2).mean()
    derivative_m=(-2/n)*sum(X* (Y- Y_pred))
    derivative_b=(-2/n)*sum(Y- Y_pred)
    m-=learning_rate*derivative_m
    b-=learning_rate*derivative_b
    print(f"Epoch{i+1}/{epochs},cost:{cost},m:{m},b:{b}")
# Out:
# Epoch1/10,cost:18.0,m:0.268,b:0.08
# Epoch2/10,cost:11.102704,m:0.47224000000000005,b:0.14232
# Epoch3/10,cost:7.0820349567999985,m:0.627808,b:0.1911392
# Epoch4/10,cost:4.7377302405222395,m:0.746221888,b:0.229647936
# Epoch5/10,cost:3.370336153805529,m:0.83627419648,b:0.26028166399999997
# Epoch6/10,cost:2.572245652152039,m:0.9046769734144,b:0.2848995789312
# Epoch7/10,cost:2.105925472375374,m:0.95655406452736,b:0.304920968947712
# Epoch8/10,cost:1.8329529316303372,m:0.9958169121944781,b:0.32142930569711614
# Epoch9/10,cost:1.672662087038685,m:1.0254514331698659,b:0.33525170485150513
# Epoch10/10,cost:1.578044764808546,m:1.047737015581405,b:0.3470195847642831
