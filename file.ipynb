# %%
with open("demo.txt","w")as file:
    file.write("hello world!")
file=open("demo.txt","r")
print(file.read())
file.close()
# Out:
# hello world!

# %%
file=open("demo.txt","w")
file.write("my name is Zaima Sohail")
file.close()

# %%
file=open("demo.txt","a")
file.write("\n iam in 5th semester i have 3.61 CGPA")
file.close()

# %%
with open("demo.txt","r")as file:
    read=file.read()
    print(read)
# Out:
# my name is zaimaiam in 5th semester i have 3.61 CGPA
#  iam in 5th semester i have 3.61 CGPA

# %%
try:
    num=int(int("enter the number:"))
    print(10/num)
except ZeroDivisionError:
    print("you are trying to divide by zero!")
except ValueError:
    print("invalid value enter")
except Exception as e:
    print(f"an excepted error occur:{e}")
# Out:
# invalid value enter
